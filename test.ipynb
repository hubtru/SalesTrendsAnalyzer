# %% [markdown]
# # Pivot

# %%
import pandas as pd

path = '/home/shady/Projects/AI_lab/Data/merged_cleaned_FE_imputed(v).csv'
df = pd.read_csv(path)

df
# Out:
#              Date        StoreID      ProductID  Quantity  Price_imputed  \
# 0      2022-05-09  4051653300272  4260705920010       1.0           3.99
# 1      2022-05-09  4051653300272  4260705920423       1.0           4.99
# 2      2022-05-09  4051653300272  4260705920416       2.0           5.99
# 3      2022-05-09  4051653300272  4260705920324       2.0           9.99
# 4      2022-05-09  4051653300272  4260705920317       1.0           9.99
# ...           ...            ...            ...       ...            ...
# 30459  2023-02-04  4051653300319  4260705920478       0.0          13.99
# 30460  2023-02-04  4051653300319  4260705920256       0.0           7.99
# 30461  2023-02-04  4051653300319  4260705920126       0.0           8.99
# 30462  2023-02-04  4051653300319  4260705920461       0.0           7.99
# 30463  2023-02-04  4051653300319  4260705920492       0.0           8.49
#
#        Year  Month  DayoftheMonth  WeekoftheMonth  DayoftheWeek  ...  \
# ...

# %%
df_pivot = df.pivot(index="Date", columns="ProductID", values="Quantity")

# sum each row to get total sales for each day and save to a new column total_quantity_day
df_pivot['total_quantity_day'] = df_pivot.sum(axis=1)
df_pivot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_pivot = df.pivot(index="Date", columns="ProductID", values="Quantity")
#       3 # sum each row to get total sales for each day and save to a new column total_quantity_day
#       4 df_pivot['total_quantity_day'] = df_pivot.sum(axis=1)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:8567, in DataFrame.pivot(self, index, columns, values)
# ...

# %% [markdown]
# # Weather

# %%
wpath = '/home/shady/Projects/AI_lab/Data/weather.csv'
weather = pd.read_csv(wpath)
weather
# Out:
#            time  weathercode (wmo code)  temperature_2m_max (°C)  \
# 0    2022-05-09                       1                     21.1
# 1    2022-05-10                      53                     23.5
# 2    2022-05-11                      51                     21.2
# 3    2022-05-12                      51                     17.7
# 4    2022-05-13                      53                     16.9
# ..          ...                     ...                      ...
# 267  2023-01-31                      53                      6.7
# 268  2023-02-01                      61                      4.9
# 269  2023-02-02                      61                      7.0
# 270  2023-02-03                      61                      8.0
# 271  2023-02-04                       3                      4.1
#
#      temperature_2m_min (°C)  temperature_2m_mean (°C)  \
# 0                        4.0                      13.7
# 1                       11.9                      17.3
# ...

# %% [markdown]
# # New Feature Engineering

# %%
# Out:
#                                                                                                                                                                                                  Quantity  \
# Date       Year Month DayoftheMonth WeekoftheMonth DayoftheWeek WeekoftheYear DayoftheYear isWeekend isWeekStart isWeekEnd isMonthStart isMonthEnd Season isHoliday StoreID       ProductID
# 2022-05-09 2022 5     9             2              2            19            129          False     False       False     False        False      Spring False     4051653300272 4260705920010       1.0
#                                                                                                                                                                                   4260705920423       1.0
# ...
